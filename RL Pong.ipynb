# %%
import pygame  # helps us make GUI games in python
import random  # help us define which direction the ball will start moving in

from pygame.transform import scale

# DQN. CNN reads in pixel data.
# reinforcement learning. trial and error.
# maximize action based on reward
# agent environment loop
# this is called Q Learning
# based on just game state. mapping of state to action is policy
# experience replay. learns from past policies


# frame rate per second
FPS = 60

# size of our window
WINDOW_WIDTH = 400
WINDOW_HEIGHT = 400

# size of our paddle
PADDLE_WIDTH = 10
PADDLE_HEIGHT = 60
# distance from the edge of the window
PADDLE_BUFFER = 10

# size of our ball
BALL_WIDTH = 10
BALL_HEIGHT = 10

# speeds of our paddle and ball
PADDLE_SPEED = 2
BALL_X_SPEED = 3
BALL_Y_SPEED = 2

# RGB colors for our paddle and ball
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)


# initialize our screen using width and height vars
screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))


def drawBall(ballXPos, ballYPos):
    ball = pygame.Rect(ballXPos, ballYPos, BALL_WIDTH, BALL_HEIGHT)
    pygame.draw.rect(screen, WHITE, ball)


# Paddle 1 is our learning agent/us
# draw to the left of the screen
def drawPaddle1(paddle1YPos):
    paddle1 = pygame.Rect(PADDLE_BUFFER,
                          paddle1YPos,
                          PADDLE_WIDTH,
                          PADDLE_HEIGHT)
    pygame.draw.rect(screen, WHITE, paddle1)


# paddle 2 is the evil AI
# draw to the right of the screen
def drawPaddle2(paddle2YPos):
    paddle2 = pygame.Rect(WINDOW_WIDTH - PADDLE_BUFFER - PADDLE_WIDTH,
                          paddle2YPos,
                          PADDLE_WIDTH,
                          PADDLE_HEIGHT)
    pygame.draw.rect(screen, WHITE, paddle2)


# update the ball, using the paddle posistions the balls positions and the
# balls directions
def updateBall(paddle1YPos, paddle2YPos,
               ballXPos, ballYPos,
               ballXDirection, ballYDirection):

    # update the x and y position
    ballXPos = ballXPos + ballXDirection * BALL_X_SPEED
    ballYPos = ballYPos + ballYDirection * BALL_Y_SPEED
    score = 0

    # checks for a collision, if the ball hits the left side,
    # our learning agent
    if (ballXPos <= PADDLE_BUFFER + PADDLE_WIDTH and
        ballYPos + BALL_HEIGHT >= paddle1YPos and
        ballYPos - BALL_HEIGHT <= paddle1YPos + PADDLE_HEIGHT):
        # switches directions
        ballXDirection = 1
    # past it
    elif (ballXPos <= 0):
        # negative score
        ballXDirection = 1
        score = -1
        return [score, paddle1YPos, paddle2YPos,
                ballXPos, ballYPos,
                ballXDirection, ballYDirection]

    # check if hits the other side
    if (ballXPos >= WINDOW_WIDTH - PADDLE_WIDTH - PADDLE_BUFFER and
        ballYPos + BALL_HEIGHT >= paddle2YPos and
        ballYPos - BALL_HEIGHT <= paddle2YPos + PADDLE_HEIGHT):
        # switch directions
        ballXDirection = -1
    # past it
    elif (ballXPos >= WINDOW_WIDTH - BALL_WIDTH):
        # positive score
        ballXDirection = -1
        score = 1
        return [score, paddle1YPos, paddle2YPos,
                ballXPos, ballYPos,
                ballXDirection, ballYDirection]

    # if it hits the top, move down
    if (ballYPos <= 0):
        ballYPos = 0
        ballYDirection = 1
    # if it hits the bottom, move up
    elif (ballYPos >= WINDOW_HEIGHT - BALL_HEIGHT):
        ballYPos = WINDOW_HEIGHT - BALL_HEIGHT
        ballYDirection = -1
    return [score, paddle1YPos, paddle2YPos,
            ballXPos, ballYPos,
            ballXDirection, ballYDirection]


# update our paddle position
# this is controlled by the action input
def updatePaddle1(action, paddle1YPos):
    # if move up
    if (action[1] == 1):
        paddle1YPos = paddle1YPos - PADDLE_SPEED
    # if move down
    if (action[2] == 1):
        paddle1YPos = paddle1YPos + PADDLE_SPEED

    # don't let it move off the screen
    if (paddle1YPos < 0):
        paddle1YPos = 0
    if (paddle1YPos > WINDOW_HEIGHT - PADDLE_HEIGHT):
        paddle1YPos = WINDOW_HEIGHT - PADDLE_HEIGHT
    return paddle1YPos

# update evil AI paddle position
# this is controlled by the position of the ball
def updatePaddle2(paddle2YPos, ballYPos):
    # move down if ball is in upper half
    if (paddle2YPos + PADDLE_HEIGHT / 2 < ballYPos + BALL_HEIGHT / 2):
        paddle2YPos = paddle2YPos + PADDLE_SPEED
    # move up if ball is in lower half
    if (paddle2YPos + PADDLE_HEIGHT / 2 > ballYPos + BALL_HEIGHT / 2):
        paddle2YPos = paddle2YPos - PADDLE_SPEED
    # don't let it hit top
    if (paddle2YPos < 0):
        paddle2YPos = 0
    # dont let it hit bottom
    if (paddle2YPos > WINDOW_HEIGHT - PADDLE_HEIGHT):
        paddle2YPos = WINDOW_HEIGHT - PADDLE_HEIGHT
    return paddle2YPos


# game class
class PongGame:
    def __init__(self):
        # random number for initial direction of ball
        num = random.randint(0, 9)
        # keep score
        self.tally = 0
        # initialie positions of paddle
        self.paddle1YPos = WINDOW_HEIGHT / 2 - PADDLE_HEIGHT / 2
        self.paddle2YPos = WINDOW_HEIGHT / 2 - PADDLE_HEIGHT / 2
        # and ball direction
        self.ballXDirection = 1
        self.ballYDirection = 1
        # starting point
        self.ballXPos = WINDOW_WIDTH / 2 - BALL_WIDTH / 2

        # randomly decide where the ball will move
        if(0 < num < 3):
            self.ballXDirection = 1
            self.ballYDirection = 1
        if (3 <= num < 5):
            self.ballXDirection = -1
            self.ballYDirection = 1
        if (5 <= num < 8):
            self.ballXDirection = 1
            self.ballYDirection = -1
        if (8 <= num < 10):
            self.ballXDirection = -1
            self.ballYDirection = -1
        # new random number
        num = random.randint(0, 9)
        # where it will start, y part
        self.ballYPos = num * (WINDOW_HEIGHT - BALL_HEIGHT) / 9
        # scaled surface
        self.scaled_surface = pygame.Surface((84, 84), depth=32)


    def getPresentFrame(self):
        # for each frame, calls the event queue, like if the main window needs
        # to be repainted
        pygame.event.pump()
        # make the background black
        screen.fill(BLACK)
        # draw our paddles
        drawPaddle1(self.paddle1YPos)
        drawPaddle2(self.paddle2YPos)
        # draw our ball
        drawBall(self.ballXPos, self.ballYPos)
        # updates the window
        pygame.display.flip()

        # copies the pixels from our surface to a 3D array. we'll use this for
        # RL
        pygame.transform.scale(pygame.display.get_surface(), (84, 84), self.scaled_surface)
        image_data = pygame.surfarray.array2d(self.scaled_surface)
        # return our surface data
        return image_data


    def getNextFrame(self, action):
        pygame.event.pump()
        score = 0
        screen.fill(BLACK)
        
        # update our paddle
        self.paddle1YPos = updatePaddle1(action, self.paddle1YPos)
        drawPaddle1(self.paddle1YPos)

        # update evil AI paddle
        self.paddle2YPos = updatePaddle2(self.paddle2YPos, self.ballYPos)
        drawPaddle2(self.paddle2YPos)
        
        # update our vars by updating ball position
        [score, self.paddle1YPos, self.paddle2YPos, self.ballXPos,
         self.ballYPos, self.ballXDirection, self.ballYDirection] = updateBall(self.paddle1YPos, self.paddle2YPos, self.ballXPos,
                                                                               self.ballYPos, self.ballXDirection, self.ballYDirection)  # draw the ball
        drawBall(self.ballXPos, self.ballYPos)
        
        # get the surface data
        # copies the pixels from our surface to a 3D array. we'll use this for
        # RL
        pygame.transform.scale(pygame.display.get_surface(), (84, 84), self.scaled_surface)
        image_data = pygame.surfarray.array2d(self.scaled_surface)
        # return our surface data
        # update the window
        pygame.display.flip()
        # record the total score
        self.tally = self.tally + score
        print("Tally is " + str(self.tally))
        # return the score and the surface data
        return [score, image_data]
# Out:
# pygame 1.9.5
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import tensorflow as tf
#import pong  # our class
import numpy as np  # math
import random  # random
# queue data structure. fast appends. and pops. replay memory
from collections import deque


# hyper params
ACTIONS = 3  # up, down, stay
# define our learning rate
GAMMA = 0.99
# for updating our gradient or training over time
INITIAL_EPSILON = 1.0
FINAL_EPSILON = 0.05
# how many frames to anneal epsilon
EXPLORE = 500000
OBSERVE = 50000
# store our experiences, the size of it
REPLAY_MEMORY = 500000
# batch size to train on
BATCH = 100
# input image size in pixels
INPUT_SIZE = 84

# create tensorflow graph
def createGraph():

    # CNN
    # creates an empty tensor with all elements set to zero with a shape
    W_conv1 = tf.Variable(tf.random_normal([8, 8, 4, 32]))
    b_conv1 = tf.Variable(tf.random_normal([32]))

    W_conv2 = tf.Variable(tf.random_normal([4, 4, 32, 64]))
    b_conv2 = tf.Variable(tf.random_normal([64]))

    W_conv3 = tf.Variable(tf.random_normal([3, 3, 64, 64]))
    b_conv3 = tf.Variable(tf.random_normal([64]))

    W_fc4 = tf.Variable(tf.random_normal([7 * 7 * 64, 784]))  # image size 7x7 due to convolutions
    b_fc4 = tf.Variable(tf.random_normal([784]))

    W_fc5 = tf.Variable(tf.random_normal([784, ACTIONS]))
    b_fc5 = tf.Variable(tf.random_normal([ACTIONS]))

    # input for pixel data
    s = tf.placeholder("float", [None, INPUT_SIZE, INPUT_SIZE, 4])

    # Computes rectified linear unit activation fucntion on  a 2-D convolution
    # given 4-D input and filter tensors. and
    conv1 = tf.nn.relu(
        tf.nn.conv2d(s, W_conv1, strides=[1, 4, 4, 1], padding="VALID") + b_conv1)

    conv2 = tf.nn.relu(
        tf.nn.conv2d(conv1, W_conv2, strides=[1, 2, 2, 1], padding="VALID") + b_conv2)

    conv3 = tf.nn.relu(
        tf.nn.conv2d(conv2, W_conv3, strides=[1, 1, 1, 1], padding="VALID") + b_conv3)

    conv3_flat = tf.reshape(conv3, [-1, 7 * 7 * 64])

    fc4 = tf.nn.relu(tf.matmul(conv3_flat, W_fc4) + b_fc4)

    fc5 = tf.matmul(fc4, W_fc5) + b_fc5

    # return input and output to the network
    return s, fc5



# deep q network. feed in pixel data to graph session
def trainGraph(inp, out, sess):

    # to calculate the argmax, we multiply the predicted output with a vector
    # with one value 1 and rest as 0
    argmax = tf.placeholder("float", [None, ACTIONS])
    gt = tf.placeholder("float", [None])  # ground truth

    # action
    action = tf.reduce_sum(tf.multiply(out, argmax), reduction_indices=1)
    # cost function we will reduce through backpropagation
    cost = tf.reduce_mean(tf.square(action - gt))
    # optimization function to reduce our minimize our cost function
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # initialize our game
    game = PongGame()

    # create a queue for experience replay to store policies
    D = deque()

    # intial frame
    frame = game.getPresentFrame()
    # convert rgb to gray scale for processing

    # stack frames, that is our input tensor
    inp_t = np.stack((frame, frame, frame, frame), axis=2)

    # saver
    saver = tf.train.Saver()

    sess.run(tf.global_variables_initializer())

    t = 0
    epsilon = INITIAL_EPSILON

    # training time
    while(1):
        # output tensor
        out_t = out.eval(feed_dict={inp: [inp_t]})[0]
        # argmax function
        argmax_t = np.zeros([ACTIONS])

        # random action with prob epsilon
        if(random.random() <= epsilon):
            maxIndex = random.randrange(ACTIONS)
        # predicted action with prob (1 - epsilon)
        else:
            maxIndex = np.argmax(out_t)
        argmax_t[maxIndex] = 1

        if epsilon > FINAL_EPSILON:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # reward tensor if score is positive
        reward_t, frame = game.getNextFrame(argmax_t)

        frame = np.reshape(frame, (INPUT_SIZE, INPUT_SIZE, 1))
        
        # new input tensor
        inp_t1 = np.append(frame, inp_t[:, :, 0:3], axis=2)

        # add our input tensor, argmax tensor, reward and updated input tensor
        # to stack of experiences
        D.append((inp_t, argmax_t, reward_t, inp_t1))

        # if we run out of replay memory, make room
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        # training iteration
        if t > OBSERVE:

            # get values from our replay memory
            minibatch = random.sample(D, BATCH)

            inp_batch = [d[0] for d in minibatch]
            argmax_batch = [d[1] for d in minibatch]
            reward_batch = [d[2] for d in minibatch]
            inp_t1_batch = [d[3] for d in minibatch]

            gt_batch = []
            out_batch = out.eval(feed_dict={inp: inp_t1_batch})

            # add values to our batch
            for i in range(0, len(minibatch)):
                gt_batch.append(reward_batch[i] + GAMMA * np.max(out_batch[i]))

            # train on that
            train_step.run(feed_dict={
                           gt: gt_batch,
                           argmax: argmax_batch,
                           inp: inp_batch
                           })

        # update our input tensor the the next frame
        inp_t = inp_t1
        t = t+1

        # print our where wer are after saving where we are
        if t % 10000 == 0:
            saver.save(sess, './' + 'pong' + '-dqn', global_step=t)

        print("TIMESTEP", t, "/ EPSILON", epsilon, "/ ACTION", maxIndex,
              "/ REWARD", reward_t, "/ Q_MAX %e" % np.max(out_t))


def main():
    # create session
    sess = tf.InteractiveSession()
    # input layer and output layer by creating graph
    inp, out = createGraph()
    # train our graph on input and output with session variables
    trainGraph(inp, out, sess)

if __name__ == "__main__":
    main()
# Out:
# Tally is 0
# TIMESTEP 1 / EPSILON 0.9999981 / ACTION 0 / REWARD 0 / Q_MAX -1.096599e+12
# Tally is 0
# TIMESTEP 2 / EPSILON 0.9999962 / ACTION 0 / REWARD 0 / Q_MAX -6.037113e+11
# Tally is 0
# TIMESTEP 3 / EPSILON 0.9999943 / ACTION 2 / REWARD 0 / Q_MAX -2.538163e+11
# Tally is 0
# TIMESTEP 4 / EPSILON 0.9999924 / ACTION 1 / REWARD 0 / Q_MAX 2.830074e+11
# Tally is 0
# TIMESTEP 5 / EPSILON 0.9999905 / ACTION 1 / REWARD 0 / Q_MAX -1.633174e+11
# Tally is 0
# TIMESTEP 6 / EPSILON 0.9999886 / ACTION 2 / REWARD 0 / Q_MAX 1.548097e+12
# Tally is 0
# TIMESTEP 7 / EPSILON 0.9999867 / ACTION 2 / REWARD 0 / Q_MAX 1.111687e+12
# Tally is 0
# TIMESTEP 8 / EPSILON 0.9999848 / ACTION 1 / REWARD 0 / Q_MAX 1.584131e+12
# Tally is 0
# TIMESTEP 9 / EPSILON 0.9999829 / ACTION 2 / REWARD 0 / Q_MAX 1.236410e+12
# Tally is 0
# TIMESTEP 10 / EPSILON 0.999981 / ACTION 1 / REWARD 0 / Q_MAX -1.052681e+12
# Tally is 0
# TIMESTEP 11 / EPSILON 0.9999791 / ACTION 0 / REWARD 0 / Q_MAX -1.912115e+12
# Tally is 0
# TIMESTEP 12 / EPSILON 0.9999772 / ACTION 0 / REWARD 0 / Q_MAX 1.041412e+12
# Tally is 0
# TIMESTEP 13 / EPSILON 0.9999753 / ACTION 1 / REWARD 0 / Q_MAX 1.312179e+12
# Tally is 0
# TIMESTEP 14 / EPSILON 0.9999734 / ACTION 2 / REWARD 0 / Q_MAX 3.662433e+10
# Tally is 0
# TIMESTEP 15 / EPSILON 0.9999715 / ACTION 2 / REWARD 0 / Q_MAX 8.153067e+11
# Tally is 0
# TIMESTEP 16 / EPSILON 0.9999696 / ACTION 0 / REWARD 0 / Q_MAX 7.574896e+11
# Tally is 0
# TIMESTEP 17 / EPSILON 0.9999677 / ACTION 1 / REWARD 0 / Q_MAX 2.834266e+12
# Tally is 0
# TIMESTEP 18 / EPSILON 0.9999658 / ACTION 1 / REWARD 0 / Q_MAX 6.716086e+11
# Tally is 0
# TIMESTEP 19 / EPSILON 0.9999639 / ACTION 0 / REWARD 0 / Q_MAX 2.121902e+12
# Tally is 0
# TIMESTEP 20 / EPSILON 0.999962 / ACTION 1 / REWARD 0 / Q_MAX 3.899557e+12
# Tally is 0
# TIMESTEP 21 / EPSILON 0.9999601 / ACTION 1 / REWARD 0 / Q_MAX 2.740889e+12
# Tally is 0
# TIMESTEP 22 / EPSILON 0.9999582 / ACTION 1 / REWARD 0 / Q_MAX 3.449578e+12
# Tally is 0
# TIMESTEP 23 / EPSILON 0.9999563 / ACTION 1 / REWARD 0 / Q_MAX 3.505465e+12
# Tally is 0
# TIMESTEP 24 / EPSILON 0.9999544 / ACTION 2 / REWARD 0 / Q_MAX 4.059921e+12
# Tally is 0
# TIMESTEP 25 / EPSILON 0.9999525 / ACTION 2 / REWARD 0 / Q_MAX 3.512246e+12
# Tally is 0
# TIMESTEP 26 / EPSILON 0.9999506 / ACTION 2 / REWARD 0 / Q_MAX 3.128630e+12
# Tally is 0
# TIMESTEP 27 / EPSILON 0.9999487 / ACTION 2 / REWARD 0 / Q_MAX 2.028755e+12
# Tally is 0
# TIMESTEP 28 / EPSILON 0.9999468 / ACTION 1 / REWARD 0 / Q_MAX 1.855070e+12
# Tally is 0
# TIMESTEP 29 / EPSILON 0.9999449 / ACTION 2 / REWARD 0 / Q_MAX 1.695161e+12
# Tally is 0
# TIMESTEP 30 / EPSILON 0.999943 / ACTION 0 / REWARD 0 / Q_MAX 2.453736e+12
# Tally is 0
# TIMESTEP 31 / EPSILON 0.9999411 / ACTION 1 / REWARD 0 / Q_MAX 2.944476e+12
# Tally is 0
# TIMESTEP 32 / EPSILON 0.9999392 / ACTION 0 / REWARD 0 / Q_MAX 4.242216e+12
# Tally is 0
# TIMESTEP 33 / EPSILON 0.9999373 / ACTION 2 / REWARD 0 / Q_MAX 4.739934e+12
# Tally is 0
# TIMESTEP 34 / EPSILON 0.9999354 / ACTION 1 / REWARD 0 / Q_MAX 3.050688e+12
# Tally is 0
# TIMESTEP 35 / EPSILON 0.9999335 / ACTION 0 / REWARD 0 / Q_MAX 1.570090e+12
# Tally is 0
# TIMESTEP 36 / EPSILON 0.9999316 / ACTION 1 / REWARD 0 / Q_MAX 3.206858e+12
# Tally is 0
# TIMESTEP 37 / EPSILON 0.9999297 / ACTION 2 / REWARD 0 / Q_MAX 3.962484e+12
# Tally is 0
# TIMESTEP 38 / EPSILON 0.9999278 / ACTION 2 / REWARD 0 / Q_MAX 3.007425e+12
# Tally is 0
# TIMESTEP 39 / EPSILON 0.9999259 / ACTION 1 / REWARD 0 / Q_MAX 2.322860e+12
# Tally is 0
# TIMESTEP 40 / EPSILON 0.999924 / ACTION 1 / REWARD 0 / Q_MAX 2.902211e+12
# Tally is 0
# TIMESTEP 41 / EPSILON 0.9999221 / ACTION 1 / REWARD 0 / Q_MAX 1.144885e+12
# Tally is 0
# TIMESTEP 42 / EPSILON 0.9999202 / ACTION 0 / REWARD 0 / Q_MAX -3.907791e+11
# Tally is 0
# TIMESTEP 43 / EPSILON 0.9999183 / ACTION 0 / REWARD 0 / Q_MAX 3.103692e+11
# Tally is 0
# TIMESTEP 44 / EPSILON 0.9999164 / ACTION 0 / REWARD 0 / Q_MAX -9.588825e+10
# Tally is 0
# TIMESTEP 45 / EPSILON 0.9999145 / ACTION 2 / REWARD 0 / Q_MAX 1.382170e+12
# Tally is 0
# TIMESTEP 46 / EPSILON 0.9999126 / ACTION 2 / REWARD 0 / Q_MAX 1.538404e+12
# Tally is 0
# TIMESTEP 47 / EPSILON 0.9999107 / ACTION 2 / REWARD 0 / Q_MAX 8.122304e+11
# Tally is 0
# TIMESTEP 48 / EPSILON 0.9999088 / ACTION 1 / REWARD 0 / Q_MAX -4.295989e+11
# Tally is 0
# TIMESTEP 49 / EPSILON 0.9999069 / ACTION 0 / REWARD 0 / Q_MAX -4.913145e+11
# Tally is 0
# TIMESTEP 50 / EPSILON 0.999905 / ACTION 1 / REWARD 0 / Q_MAX -2.699685e+10
# Tally is 0
# TIMESTEP 51 / EPSILON 0.9999031 / ACTION 1 / REWARD 0 / Q_MAX -9.445074e+11
# Tally is 0
# TIMESTEP 52 / EPSILON 0.9999012 / ACTION 1 / REWARD 0 / Q_MAX -1.910609e+12
# Tally is 0
# TIMESTEP 53 / EPSILON 0.9998993 / ACTION 0 / REWARD 0 / Q_MAX 4.437019e+11
# Tally is 0
# TIMESTEP 54 / EPSILON 0.9998974 / ACTION 1 / REWARD 0 / Q_MAX -8.491872e+11
# Tally is 0
# TIMESTEP 55 / EPSILON 0.9998955 / ACTION 2 / REWARD 0 / Q_MAX -7.846415e+11
# Tally is 0
# TIMESTEP 56 / EPSILON 0.9998936 / ACTION 1 / REWARD 0 / Q_MAX -5.608496e+11
# Tally is 0
# TIMESTEP 57 / EPSILON 0.9998917 / ACTION 2 / REWARD 0 / Q_MAX 1.432904e+12
# Tally is 0
# TIMESTEP 58 / EPSILON 0.9998898 / ACTION 1 / REWARD 0 / Q_MAX 9.726258e+11
# Tally is 0
# TIMESTEP 59 / EPSILON 0.9998879 / ACTION 0 / REWARD 0 / Q_MAX -3.391292e+11
# Tally is 0
# TIMESTEP 60 / EPSILON 0.999886 / ACTION 1 / REWARD 0 / Q_MAX -1.556872e+12
# Tally is 0
# TIMESTEP 61 / EPSILON 0.9998841 / ACTION 1 / REWARD 0 / Q_MAX -3.741171e+11
# Tally is 0
# TIMESTEP 62 / EPSILON 0.9998822 / ACTION 2 / REWARD 0 / Q_MAX -3.858860e+11
# Tally is 0
# TIMESTEP 63 / EPSILON 0.9998803 / ACTION 2 / REWARD 0 / Q_MAX 1.203514e+12
# Tally is 0
# TIMESTEP 64 / EPSILON 0.9998784000000001 / ACTION 0 / REWARD 0 / Q_MAX 8.915972e+11
# Tally is -1
# TIMESTEP 65 / EPSILON 0.9998765000000001 / ACTION 0 / REWARD -1 / Q_MAX 2.293983e+12
# Tally is -1
# TIMESTEP 66 / EPSILON 0.9998746000000001 / ACTION 2 / REWARD 0 / Q_MAX 9.971601e+11
# Tally is -1
# TIMESTEP 67 / EPSILON 0.9998727000000001 / ACTION 2 / REWARD 0 / Q_MAX -2.735914e+11
# Tally is -1
# TIMESTEP 68 / EPSILON 0.9998708000000001 / ACTION 2 / REWARD 0 / Q_MAX 5.694527e+11
# Tally is -1
# TIMESTEP 69 / EPSILON 0.9998689000000001 / ACTION 0 / REWARD 0 / Q_MAX 9.049621e+11
# Tally is -1
# TIMESTEP 70 / EPSILON 0.9998670000000001 / ACTION 1 / REWARD 0 / Q_MAX 8.015974e+11
# Tally is -1
# TIMESTEP 71 / EPSILON 0.9998651000000001 / ACTION 0 / REWARD 0 / Q_MAX -1.538045e+11
# Tally is -1
# TIMESTEP 72 / EPSILON 0.9998632000000001 / ACTION 2 / REWARD 0 / Q_MAX 8.328579e+11
# Tally is -1
# TIMESTEP 73 / EPSILON 0.9998613000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.885850e+12
# Tally is -1
# TIMESTEP 74 / EPSILON 0.9998594000000001 / ACTION 1 / REWARD 0 / Q_MAX 2.202928e+12
# Tally is -1
# TIMESTEP 75 / EPSILON 0.9998575000000001 / ACTION 1 / REWARD 0 / Q_MAX 2.007472e+12
# Tally is -1
# TIMESTEP 76 / EPSILON 0.9998556000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.977266e+12
# Tally is -1
# TIMESTEP 77 / EPSILON 0.9998537000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.657808e+12
# Tally is -1
# TIMESTEP 78 / EPSILON 0.9998518000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.050432e+12
# Tally is -1
# TIMESTEP 79 / EPSILON 0.9998499000000001 / ACTION 1 / REWARD 0 / Q_MAX 9.729524e+11
# Tally is -1
# TIMESTEP 80 / EPSILON 0.9998480000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.387337e+12
# Tally is -1
# TIMESTEP 81 / EPSILON 0.9998461000000001 / ACTION 1 / REWARD 0 / Q_MAX 4.898840e+11
# Tally is -1
# TIMESTEP 82 / EPSILON 0.9998442000000001 / ACTION 1 / REWARD 0 / Q_MAX -4.307754e+11
# Tally is -1
# TIMESTEP 83 / EPSILON 0.9998423000000001 / ACTION 0 / REWARD 0 / Q_MAX 4.533847e+11
# Tally is -1
# TIMESTEP 84 / EPSILON 0.9998404000000001 / ACTION 0 / REWARD 0 / Q_MAX 3.529540e+11
# Tally is -1
# TIMESTEP 85 / EPSILON 0.9998385000000001 / ACTION 2 / REWARD 0 / Q_MAX 5.713212e+11
# Tally is -1
# TIMESTEP 86 / EPSILON 0.9998366000000001 / ACTION 0 / REWARD 0 / Q_MAX 7.519428e+11
# Tally is -1
# TIMESTEP 87 / EPSILON 0.9998347000000001 / ACTION 2 / REWARD 0 / Q_MAX 7.007397e+11
# Tally is -1
# TIMESTEP 88 / EPSILON 0.9998328000000001 / ACTION 0 / REWARD 0 / Q_MAX 7.184496e+11
# Tally is -1
# TIMESTEP 89 / EPSILON 0.9998309000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.421933e+12
# Tally is -1
# TIMESTEP 90 / EPSILON 0.9998290000000001 / ACTION 0 / REWARD 0 / Q_MAX 5.640233e+11
# Tally is -1
# TIMESTEP 91 / EPSILON 0.9998271000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.742361e+12
# Tally is -1
# TIMESTEP 92 / EPSILON 0.9998252000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.764433e+12
# Tally is -1
# TIMESTEP 93 / EPSILON 0.9998233000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.448403e+12
# Tally is -1
# TIMESTEP 94 / EPSILON 0.9998214000000001 / ACTION 1 / REWARD 0 / Q_MAX 8.663106e+11
# Tally is -1
# TIMESTEP 95 / EPSILON 0.9998195000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.438709e+12
# Tally is -1
# TIMESTEP 96 / EPSILON 0.9998176000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.183512e+12
# Tally is -1
# TIMESTEP 97 / EPSILON 0.9998157000000001 / ACTION 2 / REWARD 0 / Q_MAX 5.410155e+11
# Tally is -1
# TIMESTEP 98 / EPSILON 0.9998138000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.935686e+12
# Tally is -1
# TIMESTEP 99 / EPSILON 0.9998119000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.056709e+12
# Tally is -1
# TIMESTEP 100 / EPSILON 0.9998100000000001 / ACTION 1 / REWARD 0 / Q_MAX 5.643306e+11
# Tally is -1
# TIMESTEP 101 / EPSILON 0.9998081000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.747145e+12
# Tally is -1
# TIMESTEP 102 / EPSILON 0.9998062000000001 / ACTION 1 / REWARD 0 / Q_MAX 3.020033e+12
# Tally is -1
# TIMESTEP 103 / EPSILON 0.9998043000000001 / ACTION 2 / REWARD 0 / Q_MAX 2.810995e+12
# Tally is -1
# TIMESTEP 104 / EPSILON 0.9998024000000001 / ACTION 1 / REWARD 0 / Q_MAX 3.648793e+12
# Tally is -1
# TIMESTEP 105 / EPSILON 0.9998005000000001 / ACTION 0 / REWARD 0 / Q_MAX 4.288570e+12
# Tally is -1
# TIMESTEP 106 / EPSILON 0.9997986000000001 / ACTION 0 / REWARD 0 / Q_MAX 4.313309e+12
# Tally is -1
# TIMESTEP 107 / EPSILON 0.9997967000000001 / ACTION 1 / REWARD 0 / Q_MAX 3.525281e+12
# Tally is -1
# TIMESTEP 108 / EPSILON 0.9997948000000001 / ACTION 0 / REWARD 0 / Q_MAX 3.134853e+12
# Tally is -1
# TIMESTEP 109 / EPSILON 0.9997929000000001 / ACTION 0 / REWARD 0 / Q_MAX 3.054097e+12
# Tally is -1
# TIMESTEP 110 / EPSILON 0.9997910000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.784164e+12
# Tally is -1
# TIMESTEP 111 / EPSILON 0.9997891000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.932645e+12
# Tally is -1
# TIMESTEP 112 / EPSILON 0.9997872000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.537505e+12
# Tally is -1
# TIMESTEP 113 / EPSILON 0.9997853000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.838880e+12
# Tally is -1
# TIMESTEP 114 / EPSILON 0.9997834000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.885318e+12
# Tally is -1
# TIMESTEP 115 / EPSILON 0.9997815000000001 / ACTION 2 / REWARD 0 / Q_MAX 2.125529e+12
# Tally is -1
# TIMESTEP 116 / EPSILON 0.9997796000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.827339e+12
# Tally is -1
# TIMESTEP 117 / EPSILON 0.9997777000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.336240e+12
# Tally is -1
# TIMESTEP 118 / EPSILON 0.9997758000000001 / ACTION 2 / REWARD 0 / Q_MAX 7.418386e+11
# Tally is -1
# TIMESTEP 119 / EPSILON 0.9997739000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.657658e+12
# Tally is -1
# TIMESTEP 120 / EPSILON 0.9997720000000001 / ACTION 2 / REWARD 0 / Q_MAX 6.696868e+11
# Tally is -1
# TIMESTEP 121 / EPSILON 0.9997701000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.767578e+12
# Tally is -1
# TIMESTEP 122 / EPSILON 0.9997682000000001 / ACTION 0 / REWARD 0 / Q_MAX 2.705456e+11
# Tally is -1
# TIMESTEP 123 / EPSILON 0.9997663000000001 / ACTION 1 / REWARD 0 / Q_MAX 6.074151e+11
# Tally is -1
# TIMESTEP 124 / EPSILON 0.9997644000000001 / ACTION 2 / REWARD 0 / Q_MAX 4.862117e+11
# Tally is -1
# TIMESTEP 125 / EPSILON 0.9997625000000001 / ACTION 2 / REWARD 0 / Q_MAX 2.618701e+11
# Tally is -1
# TIMESTEP 126 / EPSILON 0.9997606000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.764291e+12
# Tally is -1
# TIMESTEP 127 / EPSILON 0.9997587000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.026607e+12
# Tally is -1
# TIMESTEP 128 / EPSILON 0.9997568000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.357639e+12
# Tally is -1
# TIMESTEP 129 / EPSILON 0.9997549000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.421132e+12
# Tally is -1
# TIMESTEP 130 / EPSILON 0.9997530000000001 / ACTION 2 / REWARD 0 / Q_MAX 9.014523e+11
# Tally is -1
# TIMESTEP 131 / EPSILON 0.9997511000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.290551e+12
# Tally is -1
# TIMESTEP 132 / EPSILON 0.9997492000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.845946e+12
# Tally is -1
# TIMESTEP 133 / EPSILON 0.9997473000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.876716e+12
# Tally is -1
# TIMESTEP 134 / EPSILON 0.9997454000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.881803e+12
# Tally is -1
# TIMESTEP 135 / EPSILON 0.9997435000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.816212e+12
# Tally is -1
# TIMESTEP 136 / EPSILON 0.9997416000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.019017e+12
# Tally is -1
# TIMESTEP 137 / EPSILON 0.9997397000000001 / ACTION 1 / REWARD 0 / Q_MAX 9.868884e+11
# Tally is -1
# TIMESTEP 138 / EPSILON 0.9997378000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.446515e+12
# Tally is -1
# TIMESTEP 139 / EPSILON 0.9997359000000001 / ACTION 1 / REWARD 0 / Q_MAX 9.833565e+11
# Tally is -1
# TIMESTEP 140 / EPSILON 0.9997340000000001 / ACTION 2 / REWARD 0 / Q_MAX 5.036661e+11
# Tally is -1
# TIMESTEP 141 / EPSILON 0.9997321000000001 / ACTION 2 / REWARD 0 / Q_MAX 2.546941e+11
# Tally is -1
# TIMESTEP 142 / EPSILON 0.9997302000000001 / ACTION 0 / REWARD 0 / Q_MAX -1.418115e+11
# Tally is -1
# TIMESTEP 143 / EPSILON 0.9997283000000001 / ACTION 1 / REWARD 0 / Q_MAX 9.036188e+11
# Tally is -1
# TIMESTEP 144 / EPSILON 0.9997264000000001 / ACTION 0 / REWARD 0 / Q_MAX 6.586982e+11
# Tally is -1
# TIMESTEP 145 / EPSILON 0.9997245000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.097505e+12
# Tally is -1
# TIMESTEP 146 / EPSILON 0.9997226000000001 / ACTION 1 / REWARD 0 / Q_MAX 8.150604e+11
# Tally is -1
# TIMESTEP 147 / EPSILON 0.9997207000000001 / ACTION 1 / REWARD 0 / Q_MAX 9.674305e+11
# Tally is -1
# TIMESTEP 148 / EPSILON 0.9997188000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.091215e+11
# Tally is -1
# TIMESTEP 149 / EPSILON 0.9997169000000001 / ACTION 0 / REWARD 0 / Q_MAX 7.170446e+11
# Tally is -1
# TIMESTEP 150 / EPSILON 0.9997150000000001 / ACTION 0 / REWARD 0 / Q_MAX 7.552550e+11
# Tally is -1
# TIMESTEP 151 / EPSILON 0.9997131000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.118780e+12
# Tally is -1
# TIMESTEP 152 / EPSILON 0.9997112000000001 / ACTION 1 / REWARD 0 / Q_MAX 3.064328e+12
# Tally is -1
# TIMESTEP 153 / EPSILON 0.9997093000000001 / ACTION 0 / REWARD 0 / Q_MAX 5.754319e+11
# Tally is -1
# TIMESTEP 154 / EPSILON 0.9997074000000001 / ACTION 1 / REWARD 0 / Q_MAX 8.994507e+11
# Tally is -1
# TIMESTEP 155 / EPSILON 0.9997055000000001 / ACTION 2 / REWARD 0 / Q_MAX 3.027824e+11
# Tally is -1
# TIMESTEP 156 / EPSILON 0.9997036000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.078784e+12
# Tally is -1
# TIMESTEP 157 / EPSILON 0.9997017000000001 / ACTION 0 / REWARD 0 / Q_MAX 4.696668e+11
# Tally is -1
# TIMESTEP 158 / EPSILON 0.9996998000000001 / ACTION 0 / REWARD 0 / Q_MAX -7.002953e+11
# Tally is -1
# TIMESTEP 159 / EPSILON 0.9996979000000001 / ACTION 0 / REWARD 0 / Q_MAX 7.248166e+11
# Tally is -1
# TIMESTEP 160 / EPSILON 0.9996960000000001 / ACTION 0 / REWARD 0 / Q_MAX 5.527601e+11
# Tally is -1
# TIMESTEP 161 / EPSILON 0.9996941000000001 / ACTION 0 / REWARD 0 / Q_MAX 1.487413e+12
# Tally is -1
# TIMESTEP 162 / EPSILON 0.9996922000000001 / ACTION 2 / REWARD 0 / Q_MAX 1.552539e+12
# Tally is -1
# TIMESTEP 163 / EPSILON 0.9996903000000001 / ACTION 1 / REWARD 0 / Q_MAX 1.269112e+12
# Tally is -1
# TIMESTEP 164 / EPSILON 0.9996884000000001 / ACTION 0 / REWARD 0 / Q_MAX 4.514395e+11
# Tally is -1
# TIMESTEP 165 / EPSILON 0.9996865000000001 / ACTION 1 / REWARD 0 / Q_MAX -6.278232e+11
# Tally is -1
# TIMESTEP 166 / EPSILON 0.9996846000000001 / ACTION 2 / REWARD 0 / Q_MAX -2.927741e+11
# Tally is -1
# TIMESTEP 167 / EPSILON 0.9996827000000001 / ACTION 2 / REWARD 0 / Q_MAX -2.498272e+11
# Tally is -1
# TIMESTEP 168 / EPSILON 0.9996808000000001 / ACTION 1 / REWARD 0 / Q_MAX -7.183912e+10
# Tally is -1
# TIMESTEP 169 / EPSILON 0.9996789000000001 / ACTION 0 / REWARD 0 / Q_MAX -1.074543e+12
# Tally is -1
# TIMESTEP 170 / EPSILON 0.9996770000000001 / ACTION 1 / REWARD 0 / Q_MAX 5.899448e+11
# Tally is -1
# TIMESTEP 171 / EPSILON 0.9996751000000001 / ACTION 0 / REWARD 0 / Q_MAX -1.415375e+11
# Tally is -1
# TIMESTEP 172 / EPSILON 0.9996732000000002 / ACTION 2 / REWARD 0 / Q_MAX -2.485594e+11
# Tally is -1
# TIMESTEP 173 / EPSILON 0.9996713000000002 / ACTION 2 / REWARD 0 / Q_MAX 8.816053e+11
# Tally is -1
# TIMESTEP 174 / EPSILON 0.9996694000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.312305e+11
# Tally is -1
# TIMESTEP 175 / EPSILON 0.9996675000000002 / ACTION 2 / REWARD 0 / Q_MAX -1.190879e+12
# Tally is -1
# TIMESTEP 176 / EPSILON 0.9996656000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.885483e+11
# Tally is -1
# TIMESTEP 177 / EPSILON 0.9996637000000002 / ACTION 0 / REWARD 0 / Q_MAX 3.036931e+11
# Tally is -1
# TIMESTEP 178 / EPSILON 0.9996618000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.423860e+12
# Tally is -1
# TIMESTEP 179 / EPSILON 0.9996599000000002 / ACTION 2 / REWARD 0 / Q_MAX 2.340040e+12
# Tally is -1
# TIMESTEP 180 / EPSILON 0.9996580000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.951457e+12
# Tally is -1
# TIMESTEP 181 / EPSILON 0.9996561000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.369618e+12
# Tally is -1
# TIMESTEP 182 / EPSILON 0.9996542000000002 / ACTION 1 / REWARD 0 / Q_MAX 9.217264e+11
# Tally is -1
# TIMESTEP 183 / EPSILON 0.9996523000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.298900e+12
# Tally is -1
# TIMESTEP 184 / EPSILON 0.9996504000000002 / ACTION 2 / REWARD 0 / Q_MAX 9.519761e+11
# Tally is -1
# TIMESTEP 185 / EPSILON 0.9996485000000002 / ACTION 0 / REWARD 0 / Q_MAX 3.365631e+11
# Tally is -1
# TIMESTEP 186 / EPSILON 0.9996466000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.100138e+12
# Tally is -1
# TIMESTEP 187 / EPSILON 0.9996447000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.325757e+12
# Tally is -1
# TIMESTEP 188 / EPSILON 0.9996428000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.398593e+12
# Tally is -1
# TIMESTEP 189 / EPSILON 0.9996409000000002 / ACTION 2 / REWARD 0 / Q_MAX 4.391037e+11
# Tally is -1
# TIMESTEP 190 / EPSILON 0.9996390000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.910843e+11
# Tally is -1
# TIMESTEP 191 / EPSILON 0.9996371000000002 / ACTION 0 / REWARD 0 / Q_MAX 9.579547e+11
# Tally is -1
# TIMESTEP 192 / EPSILON 0.9996352000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.991791e+12
# Tally is -1
# TIMESTEP 193 / EPSILON 0.9996333000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.554428e+12
# Tally is -1
# TIMESTEP 194 / EPSILON 0.9996314000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.636590e+12
# Tally is -1
# TIMESTEP 195 / EPSILON 0.9996295000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.895051e+12
# Tally is -1
# TIMESTEP 196 / EPSILON 0.9996276000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.631643e+12
# Tally is -1
# TIMESTEP 197 / EPSILON 0.9996257000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.615079e+12
# Tally is -1
# TIMESTEP 198 / EPSILON 0.9996238000000002 / ACTION 2 / REWARD 0 / Q_MAX 9.254537e+11
# Tally is -1
# TIMESTEP 199 / EPSILON 0.9996219000000002 / ACTION 2 / REWARD 0 / Q_MAX 3.010588e+10
# Tally is -1
# TIMESTEP 200 / EPSILON 0.9996200000000002 / ACTION 2 / REWARD 0 / Q_MAX -3.768694e+11
# Tally is -1
# TIMESTEP 201 / EPSILON 0.9996181000000002 / ACTION 2 / REWARD 0 / Q_MAX -4.057943e+11
# Tally is -1
# TIMESTEP 202 / EPSILON 0.9996162000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.332840e+11
# Tally is -1
# TIMESTEP 203 / EPSILON 0.9996143000000002 / ACTION 2 / REWARD 0 / Q_MAX 4.187772e+11
# Tally is -1
# TIMESTEP 204 / EPSILON 0.9996124000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.799621e+11
# Tally is -1
# TIMESTEP 205 / EPSILON 0.9996105000000002 / ACTION 1 / REWARD 0 / Q_MAX 4.373613e+11
# Tally is -1
# TIMESTEP 206 / EPSILON 0.9996086000000002 / ACTION 2 / REWARD 0 / Q_MAX -5.666750e+10
# Tally is -1
# TIMESTEP 207 / EPSILON 0.9996067000000002 / ACTION 2 / REWARD 0 / Q_MAX 3.394950e+11
# Tally is -1
# TIMESTEP 208 / EPSILON 0.9996048000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.345990e+11
# Tally is -1
# TIMESTEP 209 / EPSILON 0.9996029000000002 / ACTION 2 / REWARD 0 / Q_MAX -6.651857e+11
# Tally is -1
# TIMESTEP 210 / EPSILON 0.9996010000000002 / ACTION 2 / REWARD 0 / Q_MAX -7.150743e+11
# Tally is -1
# TIMESTEP 211 / EPSILON 0.9995991000000002 / ACTION 2 / REWARD 0 / Q_MAX -1.234473e+12
# Tally is -1
# TIMESTEP 212 / EPSILON 0.9995972000000002 / ACTION 1 / REWARD 0 / Q_MAX 5.465178e+10
# Tally is -1
# TIMESTEP 213 / EPSILON 0.9995953000000002 / ACTION 1 / REWARD 0 / Q_MAX 5.305753e+11
# Tally is -1
# TIMESTEP 214 / EPSILON 0.9995934000000002 / ACTION 0 / REWARD 0 / Q_MAX -7.318311e+11
# Tally is -1
# TIMESTEP 215 / EPSILON 0.9995915000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.840837e+12
# Tally is -1
# TIMESTEP 216 / EPSILON 0.9995896000000002 / ACTION 0 / REWARD 0 / Q_MAX -2.715413e+12
# Tally is -1
# TIMESTEP 217 / EPSILON 0.9995877000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.941635e+12
# Tally is -1
# TIMESTEP 218 / EPSILON 0.9995858000000002 / ACTION 2 / REWARD 0 / Q_MAX -1.707902e+12
# Tally is -1
# TIMESTEP 219 / EPSILON 0.9995839000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.751903e+12
# Tally is -1
# TIMESTEP 220 / EPSILON 0.9995820000000002 / ACTION 0 / REWARD 0 / Q_MAX -4.219571e+11
# Tally is -1
# TIMESTEP 221 / EPSILON 0.9995801000000002 / ACTION 1 / REWARD 0 / Q_MAX -2.784673e+12
# Tally is -1
# TIMESTEP 222 / EPSILON 0.9995782000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.039669e+10
# Tally is -1
# TIMESTEP 223 / EPSILON 0.9995763000000002 / ACTION 2 / REWARD 0 / Q_MAX 6.233755e+11
# Tally is -1
# TIMESTEP 224 / EPSILON 0.9995744000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.348273e+12
# Tally is -1
# TIMESTEP 225 / EPSILON 0.9995725000000002 / ACTION 0 / REWARD 0 / Q_MAX -1.369125e+12
# Tally is -1
# TIMESTEP 226 / EPSILON 0.9995706000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.849496e+11
# Tally is -1
# TIMESTEP 227 / EPSILON 0.9995687000000002 / ACTION 1 / REWARD 0 / Q_MAX 9.236454e+11
# Tally is -1
# TIMESTEP 228 / EPSILON 0.9995668000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.343556e+12
# Tally is -1
# TIMESTEP 229 / EPSILON 0.9995649000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.453269e+12
# Tally is -1
# TIMESTEP 230 / EPSILON 0.9995630000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.758525e+12
# Tally is -1
# TIMESTEP 231 / EPSILON 0.9995611000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.288775e+12
# Tally is -1
# TIMESTEP 232 / EPSILON 0.9995592000000002 / ACTION 1 / REWARD 0 / Q_MAX -3.272314e+10
# Tally is -1
# TIMESTEP 233 / EPSILON 0.9995573000000002 / ACTION 1 / REWARD 0 / Q_MAX 9.820919e+11
# Tally is -1
# TIMESTEP 234 / EPSILON 0.9995554000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.476859e+12
# Tally is -1
# TIMESTEP 235 / EPSILON 0.9995535000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.462159e+12
# Tally is -1
# TIMESTEP 236 / EPSILON 0.9995516000000002 / ACTION 2 / REWARD 0 / Q_MAX 4.158552e+11
# Tally is -1
# TIMESTEP 237 / EPSILON 0.9995497000000002 / ACTION 2 / REWARD 0 / Q_MAX 5.307084e+11
# Tally is -1
# TIMESTEP 238 / EPSILON 0.9995478000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.043022e+12
# Tally is -1
# TIMESTEP 239 / EPSILON 0.9995459000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.058111e+12
# Tally is -1
# TIMESTEP 240 / EPSILON 0.9995440000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.383160e+12
# Tally is -1
# TIMESTEP 241 / EPSILON 0.9995421000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.142299e+12
# Tally is -1
# TIMESTEP 242 / EPSILON 0.9995402000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.061064e+12
# Tally is -1
# TIMESTEP 243 / EPSILON 0.9995383000000002 / ACTION 2 / REWARD 0 / Q_MAX 8.424083e+11
# Tally is -1
# TIMESTEP 244 / EPSILON 0.9995364000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.533402e+12
# Tally is -1
# TIMESTEP 245 / EPSILON 0.9995345000000002 / ACTION 0 / REWARD 0 / Q_MAX 7.122877e+11
# Tally is -1
# TIMESTEP 246 / EPSILON 0.9995326000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.600558e+12
# Tally is -1
# TIMESTEP 247 / EPSILON 0.9995307000000002 / ACTION 2 / REWARD 0 / Q_MAX 2.201033e+12
# Tally is -1
# TIMESTEP 248 / EPSILON 0.9995288000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.531554e+12
# Tally is -1
# TIMESTEP 249 / EPSILON 0.9995269000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.194565e+12
# Tally is -1
# TIMESTEP 250 / EPSILON 0.9995250000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.484574e+12
# Tally is -1
# TIMESTEP 251 / EPSILON 0.9995231000000002 / ACTION 1 / REWARD 0 / Q_MAX 3.851632e+12
# Tally is -1
# TIMESTEP 252 / EPSILON 0.9995212000000002 / ACTION 0 / REWARD 0 / Q_MAX 3.313475e+12
# Tally is -1
# TIMESTEP 253 / EPSILON 0.9995193000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.901107e+12
# Tally is -1
# TIMESTEP 254 / EPSILON 0.9995174000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.316339e+11
# Tally is -1
# TIMESTEP 255 / EPSILON 0.9995155000000002 / ACTION 2 / REWARD 0 / Q_MAX 5.854571e+11
# Tally is -1
# TIMESTEP 256 / EPSILON 0.9995136000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.654713e+12
# Tally is -1
# TIMESTEP 257 / EPSILON 0.9995117000000002 / ACTION 1 / REWARD 0 / Q_MAX 5.714716e+10
# Tally is -1
# TIMESTEP 258 / EPSILON 0.9995098000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.276683e+12
# Tally is -1
# TIMESTEP 259 / EPSILON 0.9995079000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.882766e+12
# Tally is -1
# TIMESTEP 260 / EPSILON 0.9995060000000002 / ACTION 1 / REWARD 0 / Q_MAX 3.518077e+12
# Tally is -1
# TIMESTEP 261 / EPSILON 0.9995041000000002 / ACTION 2 / REWARD 0 / Q_MAX 2.026110e+12
# Tally is -1
# TIMESTEP 262 / EPSILON 0.9995022000000002 / ACTION 0 / REWARD 0 / Q_MAX 2.373588e+12
# Tally is -1
# TIMESTEP 263 / EPSILON 0.9995003000000002 / ACTION 2 / REWARD 0 / Q_MAX 5.175723e+11
# Tally is -1
# TIMESTEP 264 / EPSILON 0.9994984000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.525523e+12
# Tally is -1
# TIMESTEP 265 / EPSILON 0.9994965000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.042801e+12
# Tally is -1
# TIMESTEP 266 / EPSILON 0.9994946000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.845198e+12
# Tally is -1
# TIMESTEP 267 / EPSILON 0.9994927000000002 / ACTION 0 / REWARD 0 / Q_MAX 2.383836e+12
# Tally is -1
# TIMESTEP 268 / EPSILON 0.9994908000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.598708e+12
# Tally is -1
# TIMESTEP 269 / EPSILON 0.9994889000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.556236e+12
# Tally is -1
# TIMESTEP 270 / EPSILON 0.9994870000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.952095e+12
# Tally is -1
# TIMESTEP 271 / EPSILON 0.9994851000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.269307e+12
# Tally is -1
# TIMESTEP 272 / EPSILON 0.9994832000000002 / ACTION 2 / REWARD 0 / Q_MAX 2.039684e+12
# Tally is -1
# TIMESTEP 273 / EPSILON 0.9994813000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.958341e+12
# Tally is -1
# TIMESTEP 274 / EPSILON 0.9994794000000002 / ACTION 0 / REWARD 0 / Q_MAX 2.352462e+12
# Tally is -1
# TIMESTEP 275 / EPSILON 0.9994775000000002 / ACTION 1 / REWARD 0 / Q_MAX 7.395921e+11
# Tally is -1
# TIMESTEP 276 / EPSILON 0.9994756000000002 / ACTION 1 / REWARD 0 / Q_MAX 1.060303e+12
# Tally is -1
# TIMESTEP 277 / EPSILON 0.9994737000000002 / ACTION 0 / REWARD 0 / Q_MAX 2.020872e+12
# Tally is -1
# TIMESTEP 278 / EPSILON 0.9994718000000002 / ACTION 0 / REWARD 0 / Q_MAX 2.478862e+12
# Tally is -1
# TIMESTEP 279 / EPSILON 0.9994699000000002 / ACTION 1 / REWARD 0 / Q_MAX 3.338119e+12
# Tally is -1
# TIMESTEP 280 / EPSILON 0.9994680000000002 / ACTION 2 / REWARD 0 / Q_MAX 1.502935e+12
# Tally is -1
# TIMESTEP 281 / EPSILON 0.9994661000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.091838e+12
# Tally is -1
# TIMESTEP 282 / EPSILON 0.9994642000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.249323e+12
# Tally is -1
# TIMESTEP 283 / EPSILON 0.9994623000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.592019e+12
# Tally is -1
# TIMESTEP 284 / EPSILON 0.9994604000000002 / ACTION 1 / REWARD 0 / Q_MAX 2.484177e+12
# Tally is -1
# TIMESTEP 285 / EPSILON 0.9994585000000002 / ACTION 0 / REWARD 0 / Q_MAX 1.137688e+12
# Tally is -1
# TIMESTEP 286 / EPSILON 0.9994566000000003 / ACTION 0 / REWARD 0 / Q_MAX 7.624800e+11
# Tally is -1
# TIMESTEP 287 / EPSILON 0.9994547000000003 / ACTION 1 / REWARD 0 / Q_MAX 6.448018e+11
# Tally is -1
# TIMESTEP 288 / EPSILON 0.9994528000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.331690e+11
# Tally is -1
# TIMESTEP 289 / EPSILON 0.9994509000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.713734e+10
# Tally is -1
# TIMESTEP 290 / EPSILON 0.9994490000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.751332e+12
# Tally is -1
# TIMESTEP 291 / EPSILON 0.9994471000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.278565e+11
# Tally is -1
# TIMESTEP 292 / EPSILON 0.9994452000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.453829e+12
# Tally is -1
# TIMESTEP 293 / EPSILON 0.9994433000000003 / ACTION 2 / REWARD 0 / Q_MAX 9.739895e+11
# Tally is -1
# TIMESTEP 294 / EPSILON 0.9994414000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.722090e+11
# Tally is -1
# TIMESTEP 295 / EPSILON 0.9994395000000003 / ACTION 2 / REWARD 0 / Q_MAX 4.617307e+11
# Tally is -1
# TIMESTEP 296 / EPSILON 0.9994376000000003 / ACTION 1 / REWARD 0 / Q_MAX 4.305028e+11
# Tally is -1
# TIMESTEP 297 / EPSILON 0.9994357000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.471321e+11
# Tally is -1
# TIMESTEP 298 / EPSILON 0.9994338000000003 / ACTION 1 / REWARD 0 / Q_MAX 8.379016e+11
# Tally is -1
# TIMESTEP 299 / EPSILON 0.9994319000000003 / ACTION 1 / REWARD 0 / Q_MAX -4.827239e+11
# Tally is -1
# TIMESTEP 300 / EPSILON 0.9994300000000003 / ACTION 1 / REWARD 0 / Q_MAX 7.383356e+11
# Tally is -1
# TIMESTEP 301 / EPSILON 0.9994281000000003 / ACTION 1 / REWARD 0 / Q_MAX 8.608492e+11
# Tally is -1
# TIMESTEP 302 / EPSILON 0.9994262000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.006322e+12
# Tally is -1
# TIMESTEP 303 / EPSILON 0.9994243000000003 / ACTION 2 / REWARD 0 / Q_MAX 4.384582e+11
# Tally is -1
# TIMESTEP 304 / EPSILON 0.9994224000000003 / ACTION 1 / REWARD 0 / Q_MAX 8.319579e+11
# Tally is -1
# TIMESTEP 305 / EPSILON 0.9994205000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.066943e+12
# Tally is -1
# TIMESTEP 306 / EPSILON 0.9994186000000003 / ACTION 0 / REWARD 0 / Q_MAX 7.872005e+11
# Tally is -1
# TIMESTEP 307 / EPSILON 0.9994167000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.044161e+12
# Tally is -1
# TIMESTEP 308 / EPSILON 0.9994148000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.191424e+12
# Tally is -1
# TIMESTEP 309 / EPSILON 0.9994129000000003 / ACTION 0 / REWARD 0 / Q_MAX 4.203991e+11
# Tally is -1
# TIMESTEP 310 / EPSILON 0.9994110000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.078711e+11
# Tally is -1
# TIMESTEP 311 / EPSILON 0.9994091000000003 / ACTION 2 / REWARD 0 / Q_MAX 4.595987e+11
# Tally is -1
# TIMESTEP 312 / EPSILON 0.9994072000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.575646e+11
# Tally is -1
# TIMESTEP 313 / EPSILON 0.9994053000000003 / ACTION 1 / REWARD 0 / Q_MAX 7.634502e+11
# Tally is -1
# TIMESTEP 314 / EPSILON 0.9994034000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.543465e+11
# Tally is -1
# TIMESTEP 315 / EPSILON 0.9994015000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.771326e+11
# Tally is -1
# TIMESTEP 316 / EPSILON 0.9993996000000003 / ACTION 1 / REWARD 0 / Q_MAX 3.084241e+11
# Tally is -1
# TIMESTEP 317 / EPSILON 0.9993977000000003 / ACTION 1 / REWARD 0 / Q_MAX 2.281467e+11
# Tally is -1
# TIMESTEP 318 / EPSILON 0.9993958000000003 / ACTION 1 / REWARD 0 / Q_MAX 5.366816e+11
# Tally is -2
# TIMESTEP 319 / EPSILON 0.9993939000000003 / ACTION 0 / REWARD -1 / Q_MAX 2.779084e+11
# Tally is -2
# TIMESTEP 320 / EPSILON 0.9993920000000003 / ACTION 0 / REWARD 0 / Q_MAX 6.840377e+10
# Tally is -2
# TIMESTEP 321 / EPSILON 0.9993901000000003 / ACTION 2 / REWARD 0 / Q_MAX -1.451852e+11
# Tally is -2
# TIMESTEP 322 / EPSILON 0.9993882000000003 / ACTION 1 / REWARD 0 / Q_MAX -6.809328e+10
# Tally is -2
# TIMESTEP 323 / EPSILON 0.9993863000000003 / ACTION 0 / REWARD 0 / Q_MAX 4.133918e+11
# Tally is -2
# TIMESTEP 324 / EPSILON 0.9993844000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.216849e+11
# Tally is -2
# TIMESTEP 325 / EPSILON 0.9993825000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.468780e+10
# Tally is -2
# TIMESTEP 326 / EPSILON 0.9993806000000003 / ACTION 2 / REWARD 0 / Q_MAX 8.652066e+10
# Tally is -2
# TIMESTEP 327 / EPSILON 0.9993787000000003 / ACTION 0 / REWARD 0 / Q_MAX 6.968804e+11
# Tally is -2
# TIMESTEP 328 / EPSILON 0.9993768000000003 / ACTION 0 / REWARD 0 / Q_MAX 3.774908e+11
# Tally is -2
# TIMESTEP 329 / EPSILON 0.9993749000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.716308e+11
# Tally is -2
# TIMESTEP 330 / EPSILON 0.9993730000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.015571e+12
# Tally is -2
# TIMESTEP 331 / EPSILON 0.9993711000000003 / ACTION 2 / REWARD 0 / Q_MAX 4.467018e+11
# Tally is -2
# TIMESTEP 332 / EPSILON 0.9993692000000003 / ACTION 0 / REWARD 0 / Q_MAX 8.131413e+11
# Tally is -2
# TIMESTEP 333 / EPSILON 0.9993673000000003 / ACTION 1 / REWARD 0 / Q_MAX 7.792706e+11
# Tally is -2
# TIMESTEP 334 / EPSILON 0.9993654000000003 / ACTION 1 / REWARD 0 / Q_MAX 7.124645e+11
# Tally is -2
# TIMESTEP 335 / EPSILON 0.9993635000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.158930e+11
# Tally is -2
# TIMESTEP 336 / EPSILON 0.9993616000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.689348e+11
# Tally is -2
# TIMESTEP 337 / EPSILON 0.9993597000000003 / ACTION 0 / REWARD 0 / Q_MAX 3.609359e+11
# Tally is -2
# TIMESTEP 338 / EPSILON 0.9993578000000003 / ACTION 2 / REWARD 0 / Q_MAX 5.967277e+11
# Tally is -2
# TIMESTEP 339 / EPSILON 0.9993559000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.059256e+12
# Tally is -2
# TIMESTEP 340 / EPSILON 0.9993540000000003 / ACTION 0 / REWARD 0 / Q_MAX 9.989843e+11
# Tally is -2
# TIMESTEP 341 / EPSILON 0.9993521000000003 / ACTION 0 / REWARD 0 / Q_MAX 5.939901e+11
# Tally is -2
# TIMESTEP 342 / EPSILON 0.9993502000000003 / ACTION 1 / REWARD 0 / Q_MAX 4.100039e+11
# Tally is -2
# TIMESTEP 343 / EPSILON 0.9993483000000003 / ACTION 1 / REWARD 0 / Q_MAX 4.528009e+11
# Tally is -2
# TIMESTEP 344 / EPSILON 0.9993464000000003 / ACTION 2 / REWARD 0 / Q_MAX -5.184476e+10
# Tally is -2
# TIMESTEP 345 / EPSILON 0.9993445000000003 / ACTION 0 / REWARD 0 / Q_MAX 8.900864e+11
# Tally is -2
# TIMESTEP 346 / EPSILON 0.9993426000000003 / ACTION 2 / REWARD 0 / Q_MAX 9.555600e+11
# Tally is -2
# TIMESTEP 347 / EPSILON 0.9993407000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.042128e+12
# Tally is -2
# TIMESTEP 348 / EPSILON 0.9993388000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.116073e+12
# Tally is -2
# TIMESTEP 349 / EPSILON 0.9993369000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.268634e+12
# Tally is -2
# TIMESTEP 350 / EPSILON 0.9993350000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.110821e+12
# Tally is -2
# TIMESTEP 351 / EPSILON 0.9993331000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.575066e+12
# Tally is -2
# TIMESTEP 352 / EPSILON 0.9993312000000003 / ACTION 2 / REWARD 0 / Q_MAX -2.508933e+11
# Tally is -2
# TIMESTEP 353 / EPSILON 0.9993293000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.650046e+11
# Tally is -2
# TIMESTEP 354 / EPSILON 0.9993274000000003 / ACTION 2 / REWARD 0 / Q_MAX 8.701717e+11
# Tally is -2
# TIMESTEP 355 / EPSILON 0.9993255000000003 / ACTION 1 / REWARD 0 / Q_MAX 7.005306e+11
# Tally is -2
# TIMESTEP 356 / EPSILON 0.9993236000000003 / ACTION 1 / REWARD 0 / Q_MAX 5.846044e+11
# Tally is -2
# TIMESTEP 357 / EPSILON 0.9993217000000003 / ACTION 2 / REWARD 0 / Q_MAX -5.930474e+10
# Tally is -2
# TIMESTEP 358 / EPSILON 0.9993198000000003 / ACTION 0 / REWARD 0 / Q_MAX -5.923975e+11
# Tally is -2
# TIMESTEP 359 / EPSILON 0.9993179000000003 / ACTION 2 / REWARD 0 / Q_MAX -3.929545e+11
# Tally is -2
# TIMESTEP 360 / EPSILON 0.9993160000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.369582e+11
# Tally is -2
# TIMESTEP 361 / EPSILON 0.9993141000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.356172e+11
# Tally is -2
# TIMESTEP 362 / EPSILON 0.9993122000000003 / ACTION 2 / REWARD 0 / Q_MAX -5.574617e+11
# Tally is -2
# TIMESTEP 363 / EPSILON 0.9993103000000003 / ACTION 2 / REWARD 0 / Q_MAX 3.608451e+11
# Tally is -2
# TIMESTEP 364 / EPSILON 0.9993084000000003 / ACTION 2 / REWARD 0 / Q_MAX -1.349369e+11
# Tally is -2
# TIMESTEP 365 / EPSILON 0.9993065000000003 / ACTION 1 / REWARD 0 / Q_MAX 2.049191e+12
# Tally is -2
# TIMESTEP 366 / EPSILON 0.9993046000000003 / ACTION 1 / REWARD 0 / Q_MAX 8.270255e+11
# Tally is -2
# TIMESTEP 367 / EPSILON 0.9993027000000003 / ACTION 1 / REWARD 0 / Q_MAX 2.676679e+11
# Tally is -2
# TIMESTEP 368 / EPSILON 0.9993008000000003 / ACTION 0 / REWARD 0 / Q_MAX -8.261924e+11
# Tally is -2
# TIMESTEP 369 / EPSILON 0.9992989000000003 / ACTION 0 / REWARD 0 / Q_MAX -1.179428e+12
# Tally is -2
# TIMESTEP 370 / EPSILON 0.9992970000000003 / ACTION 1 / REWARD 0 / Q_MAX -2.761035e+11
# Tally is -2
# TIMESTEP 371 / EPSILON 0.9992951000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.151099e+11
# Tally is -2
# TIMESTEP 372 / EPSILON 0.9992932000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.003622e+12
# Tally is -2
# TIMESTEP 373 / EPSILON 0.9992913000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.871981e+12
# Tally is -2
# TIMESTEP 374 / EPSILON 0.9992894000000003 / ACTION 1 / REWARD 0 / Q_MAX -4.016786e+11
# Tally is -2
# TIMESTEP 375 / EPSILON 0.9992875000000003 / ACTION 2 / REWARD 0 / Q_MAX 4.183115e+11
# Tally is -2
# TIMESTEP 376 / EPSILON 0.9992856000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.541131e+12
# Tally is -2
# TIMESTEP 377 / EPSILON 0.9992837000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.948531e+12
# Tally is -2
# TIMESTEP 378 / EPSILON 0.9992818000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.717707e+12
# Tally is -2
# TIMESTEP 379 / EPSILON 0.9992799000000003 / ACTION 1 / REWARD 0 / Q_MAX 4.159071e+12
# Tally is -2
# TIMESTEP 380 / EPSILON 0.9992780000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.722821e+12
# Tally is -2
# TIMESTEP 381 / EPSILON 0.9992761000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.239214e+12
# Tally is -2
# TIMESTEP 382 / EPSILON 0.9992742000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.687582e+12
# Tally is -2
# TIMESTEP 383 / EPSILON 0.9992723000000003 / ACTION 2 / REWARD 0 / Q_MAX 2.661313e+12
# Tally is -2
# TIMESTEP 384 / EPSILON 0.9992704000000003 / ACTION 0 / REWARD 0 / Q_MAX 3.640935e+12
# Tally is -2
# TIMESTEP 385 / EPSILON 0.9992685000000003 / ACTION 1 / REWARD 0 / Q_MAX 2.578287e+12
# Tally is -2
# TIMESTEP 386 / EPSILON 0.9992666000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.342958e+12
# Tally is -2
# TIMESTEP 387 / EPSILON 0.9992647000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.748772e+12
# Tally is -2
# TIMESTEP 388 / EPSILON 0.9992628000000003 / ACTION 1 / REWARD 0 / Q_MAX 3.442963e+12
# Tally is -2
# TIMESTEP 389 / EPSILON 0.9992609000000003 / ACTION 0 / REWARD 0 / Q_MAX 1.888319e+12
# Tally is -2
# TIMESTEP 390 / EPSILON 0.9992590000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.104508e+12
# Tally is -2
# TIMESTEP 391 / EPSILON 0.9992571000000003 / ACTION 1 / REWARD 0 / Q_MAX 1.625862e+12
# Tally is -2
# TIMESTEP 392 / EPSILON 0.9992552000000003 / ACTION 1 / REWARD 0 / Q_MAX 4.454357e+11
# Tally is -2
# TIMESTEP 393 / EPSILON 0.9992533000000003 / ACTION 1 / REWARD 0 / Q_MAX 2.756795e+12
# Tally is -2
# TIMESTEP 394 / EPSILON 0.9992514000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.069619e+12
# Tally is -2
# TIMESTEP 395 / EPSILON 0.9992495000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.620602e+12
# Tally is -2
# TIMESTEP 396 / EPSILON 0.9992476000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.779755e+12
# Tally is -2
# TIMESTEP 397 / EPSILON 0.9992457000000003 / ACTION 0 / REWARD 0 / Q_MAX 2.423722e+12
# Tally is -2
# TIMESTEP 398 / EPSILON 0.9992438000000003 / ACTION 2 / REWARD 0 / Q_MAX 6.197652e+11
# Tally is -2
# TIMESTEP 399 / EPSILON 0.9992419000000003 / ACTION 2 / REWARD 0 / Q_MAX 1.945295e+12
# Tally is -2
# TIMESTEP 400 / EPSILON 0.9992400000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.731099e+12
# Tally is -2
# TIMESTEP 401 / EPSILON 0.9992381000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.960690e+12
# Tally is -2
# TIMESTEP 402 / EPSILON 0.9992362000000004 / ACTION 0 / REWARD 0 / Q_MAX 8.411783e+11
# Tally is -2
# TIMESTEP 403 / EPSILON 0.9992343000000004 / ACTION 1 / REWARD 0 / Q_MAX 6.496329e+11
# Tally is -2
# TIMESTEP 404 / EPSILON 0.9992324000000004 / ACTION 2 / REWARD 0 / Q_MAX 2.485543e+12
# Tally is -2
# TIMESTEP 405 / EPSILON 0.9992305000000004 / ACTION 2 / REWARD 0 / Q_MAX 2.690676e+12
# Tally is -2
# TIMESTEP 406 / EPSILON 0.9992286000000004 / ACTION 0 / REWARD 0 / Q_MAX 5.286725e+11
# Tally is -2
# TIMESTEP 407 / EPSILON 0.9992267000000004 / ACTION 0 / REWARD 0 / Q_MAX 7.848024e+11
# Tally is -2
# TIMESTEP 408 / EPSILON 0.9992248000000004 / ACTION 0 / REWARD 0 / Q_MAX 7.962672e+11
# Tally is -2
# TIMESTEP 409 / EPSILON 0.9992229000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.989923e+12
# Tally is -2
# TIMESTEP 410 / EPSILON 0.9992210000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.673958e+12
# Tally is -2
# TIMESTEP 411 / EPSILON 0.9992191000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.780245e+12
# Tally is -2
# TIMESTEP 412 / EPSILON 0.9992172000000004 / ACTION 2 / REWARD 0 / Q_MAX 3.836622e+12
# Tally is -2
# TIMESTEP 413 / EPSILON 0.9992153000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.023687e+12
# Tally is -2
# TIMESTEP 414 / EPSILON 0.9992134000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.281348e+12
# Tally is -2
# TIMESTEP 415 / EPSILON 0.9992115000000004 / ACTION 2 / REWARD 0 / Q_MAX 7.979476e+11
# Tally is -2
# TIMESTEP 416 / EPSILON 0.9992096000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.238917e+12
# Tally is -2
# TIMESTEP 417 / EPSILON 0.9992077000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.967109e+12
# Tally is -2
# TIMESTEP 418 / EPSILON 0.9992058000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.392823e+12
# Tally is -2
# TIMESTEP 419 / EPSILON 0.9992039000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.575361e+12
# Tally is -2
# TIMESTEP 420 / EPSILON 0.9992020000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.078825e+12
# Tally is -2
# TIMESTEP 421 / EPSILON 0.9992001000000004 / ACTION 1 / REWARD 0 / Q_MAX -1.041379e+12
# Tally is -2
# TIMESTEP 422 / EPSILON 0.9991982000000004 / ACTION 0 / REWARD 0 / Q_MAX 4.458401e+11
# Tally is -2
# TIMESTEP 423 / EPSILON 0.9991963000000004 / ACTION 2 / REWARD 0 / Q_MAX 7.605537e+11
# Tally is -2
# TIMESTEP 424 / EPSILON 0.9991944000000004 / ACTION 1 / REWARD 0 / Q_MAX -7.043662e+09
# Tally is -2
# TIMESTEP 425 / EPSILON 0.9991925000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.180891e+12
# Tally is -2
# TIMESTEP 426 / EPSILON 0.9991906000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.633270e+11
# Tally is -2
# TIMESTEP 427 / EPSILON 0.9991887000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.855571e+12
# Tally is -2
# TIMESTEP 428 / EPSILON 0.9991868000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.927815e+12
# Tally is -2
# TIMESTEP 429 / EPSILON 0.9991849000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.104286e+12
# Tally is -2
# TIMESTEP 430 / EPSILON 0.9991830000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.676634e+12
# Tally is -2
# TIMESTEP 431 / EPSILON 0.9991811000000004 / ACTION 2 / REWARD 0 / Q_MAX -5.129989e+10
# Tally is -2
# TIMESTEP 432 / EPSILON 0.9991792000000004 / ACTION 0 / REWARD 0 / Q_MAX -1.183858e+11
# Tally is -2
# TIMESTEP 433 / EPSILON 0.9991773000000004 / ACTION 1 / REWARD 0 / Q_MAX -2.052981e+11
# Tally is -2
# TIMESTEP 434 / EPSILON 0.9991754000000004 / ACTION 1 / REWARD 0 / Q_MAX 4.136454e+11
# Tally is -2
# TIMESTEP 435 / EPSILON 0.9991735000000004 / ACTION 1 / REWARD 0 / Q_MAX 3.179366e+11
# Tally is -2
# TIMESTEP 436 / EPSILON 0.9991716000000004 / ACTION 2 / REWARD 0 / Q_MAX 7.733608e+11
# Tally is -2
# TIMESTEP 437 / EPSILON 0.9991697000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.679991e+11
# Tally is -2
# TIMESTEP 438 / EPSILON 0.9991678000000004 / ACTION 2 / REWARD 0 / Q_MAX 3.067867e+11
# Tally is -2
# TIMESTEP 439 / EPSILON 0.9991659000000004 / ACTION 2 / REWARD 0 / Q_MAX -4.490870e+11
# Tally is -2
# TIMESTEP 440 / EPSILON 0.9991640000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.384033e+11
# Tally is -2
# TIMESTEP 441 / EPSILON 0.9991621000000004 / ACTION 2 / REWARD 0 / Q_MAX 6.262967e+10
# Tally is -2
# TIMESTEP 442 / EPSILON 0.9991602000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.244721e+11
# Tally is -2
# TIMESTEP 443 / EPSILON 0.9991583000000004 / ACTION 1 / REWARD 0 / Q_MAX 6.902501e+11
# Tally is -2
# TIMESTEP 444 / EPSILON 0.9991564000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.309831e+11
# Tally is -2
# TIMESTEP 445 / EPSILON 0.9991545000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.754319e+11
# Tally is -2
# TIMESTEP 446 / EPSILON 0.9991526000000004 / ACTION 0 / REWARD 0 / Q_MAX -4.601337e+11
# Tally is -2
# TIMESTEP 447 / EPSILON 0.9991507000000004 / ACTION 2 / REWARD 0 / Q_MAX 6.554690e+11
# Tally is -2
# TIMESTEP 448 / EPSILON 0.9991488000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.189526e+12
# Tally is -2
# TIMESTEP 449 / EPSILON 0.9991469000000004 / ACTION 0 / REWARD 0 / Q_MAX 9.624407e+11
# Tally is -2
# TIMESTEP 450 / EPSILON 0.9991450000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.081907e+12
# Tally is -2
# TIMESTEP 451 / EPSILON 0.9991431000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.377867e+12
# Tally is -2
# TIMESTEP 452 / EPSILON 0.9991412000000004 / ACTION 1 / REWARD 0 / Q_MAX 8.821685e+11
# Tally is -2
# TIMESTEP 453 / EPSILON 0.9991393000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.979788e+12
# Tally is -2
# TIMESTEP 454 / EPSILON 0.9991374000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.238487e+12
# Tally is -2
# TIMESTEP 455 / EPSILON 0.9991355000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.211264e+12
# Tally is -2
# TIMESTEP 456 / EPSILON 0.9991336000000004 / ACTION 2 / REWARD 0 / Q_MAX 2.316829e+12
# Tally is -2
# TIMESTEP 457 / EPSILON 0.9991317000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.604863e+12
# Tally is -2
# TIMESTEP 458 / EPSILON 0.9991298000000004 / ACTION 0 / REWARD 0 / Q_MAX 2.078225e+12
# Tally is -2
# TIMESTEP 459 / EPSILON 0.9991279000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.333326e+12
# Tally is -2
# TIMESTEP 460 / EPSILON 0.9991260000000004 / ACTION 0 / REWARD 0 / Q_MAX 2.947647e+12
# Tally is -2
# TIMESTEP 461 / EPSILON 0.9991241000000004 / ACTION 2 / REWARD 0 / Q_MAX 3.204445e+12
# Tally is -2
# TIMESTEP 462 / EPSILON 0.9991222000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.054282e+12
# Tally is -2
# TIMESTEP 463 / EPSILON 0.9991203000000004 / ACTION 1 / REWARD 0 / Q_MAX 3.254766e+12
# Tally is -2
# TIMESTEP 464 / EPSILON 0.9991184000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.634887e+12
# Tally is -2
# TIMESTEP 465 / EPSILON 0.9991165000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.193425e+12
# Tally is -2
# TIMESTEP 466 / EPSILON 0.9991146000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.766443e+12
# Tally is -2
# TIMESTEP 467 / EPSILON 0.9991127000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.886466e+12
# Tally is -2
# TIMESTEP 468 / EPSILON 0.9991108000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.385385e+12
# Tally is -2
# TIMESTEP 469 / EPSILON 0.9991089000000004 / ACTION 2 / REWARD 0 / Q_MAX 3.050890e+12
# Tally is -2
# TIMESTEP 470 / EPSILON 0.9991070000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.669718e+12
# Tally is -2
# TIMESTEP 471 / EPSILON 0.9991051000000004 / ACTION 1 / REWARD 0 / Q_MAX 9.423782e+11
# Tally is -2
# TIMESTEP 472 / EPSILON 0.9991032000000004 / ACTION 2 / REWARD 0 / Q_MAX 2.714834e+12
# Tally is -2
# TIMESTEP 473 / EPSILON 0.9991013000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.004964e+12
# Tally is -2
# TIMESTEP 474 / EPSILON 0.9990994000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.803770e+12
# Tally is -2
# TIMESTEP 475 / EPSILON 0.9990975000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.315342e+12
# Tally is -2
# TIMESTEP 476 / EPSILON 0.9990956000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.836311e+12
# Tally is -2
# TIMESTEP 477 / EPSILON 0.9990937000000004 / ACTION 2 / REWARD 0 / Q_MAX 6.173325e+11
# Tally is -2
# TIMESTEP 478 / EPSILON 0.9990918000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.223389e+12
# Tally is -2
# TIMESTEP 479 / EPSILON 0.9990899000000004 / ACTION 2 / REWARD 0 / Q_MAX -3.568020e+11
# Tally is -2
# TIMESTEP 480 / EPSILON 0.9990880000000004 / ACTION 0 / REWARD 0 / Q_MAX -3.964747e+11
# Tally is -2
# TIMESTEP 481 / EPSILON 0.9990861000000004 / ACTION 2 / REWARD 0 / Q_MAX 7.454794e+11
# Tally is -2
# TIMESTEP 482 / EPSILON 0.9990842000000004 / ACTION 0 / REWARD 0 / Q_MAX -3.328959e+11
# Tally is -2
# TIMESTEP 483 / EPSILON 0.9990823000000004 / ACTION 1 / REWARD 0 / Q_MAX -5.124249e+11
# Tally is -2
# TIMESTEP 484 / EPSILON 0.9990804000000004 / ACTION 0 / REWARD 0 / Q_MAX 4.459165e+11
# Tally is -2
# TIMESTEP 485 / EPSILON 0.9990785000000004 / ACTION 0 / REWARD 0 / Q_MAX 3.623882e+11
# Tally is -2
# TIMESTEP 486 / EPSILON 0.9990766000000004 / ACTION 0 / REWARD 0 / Q_MAX 2.188811e+12
# Tally is -2
# TIMESTEP 487 / EPSILON 0.9990747000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.514410e+10
# Tally is -2
# TIMESTEP 488 / EPSILON 0.9990728000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.131643e+12
# Tally is -2
# TIMESTEP 489 / EPSILON 0.9990709000000004 / ACTION 2 / REWARD 0 / Q_MAX 2.439121e+11
# Tally is -2
# TIMESTEP 490 / EPSILON 0.9990690000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.164743e+12
# Tally is -2
# TIMESTEP 491 / EPSILON 0.9990671000000004 / ACTION 1 / REWARD 0 / Q_MAX -1.023737e+11
# Tally is -2
# TIMESTEP 492 / EPSILON 0.9990652000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.710433e+12
# Tally is -2
# TIMESTEP 493 / EPSILON 0.9990633000000004 / ACTION 0 / REWARD 0 / Q_MAX 1.996478e+12
# Tally is -2
# TIMESTEP 494 / EPSILON 0.9990614000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.349583e+12
# Tally is -2
# TIMESTEP 495 / EPSILON 0.9990595000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.812715e+12
# Tally is -2
# TIMESTEP 496 / EPSILON 0.9990576000000004 / ACTION 1 / REWARD 0 / Q_MAX 9.446541e+11
# Tally is -2
# TIMESTEP 497 / EPSILON 0.9990557000000004 / ACTION 1 / REWARD 0 / Q_MAX 1.057327e+12
# Tally is -2
# TIMESTEP 498 / EPSILON 0.9990538000000004 / ACTION 2 / REWARD 0 / Q_MAX 1.362893e+12
# Tally is -2
# TIMESTEP 499 / EPSILON 0.9990519000000004 / ACTION 1 / REWARD 0 / Q_MAX 8.366660e+11
# Tally is -2
# TIMESTEP 500 / EPSILON 0.9990500000000004 / ACTION 1 / REWARD 0 / Q_MAX 2.722764e+11
# Tally is -2
# TIMESTEP 501 / EPSILON 0.9990481000000004 / ACTION 0 / REWARD 0 / Q_MAX 2.216350e+11
# Tally is -2
# ...
# Tally is -73
# TIMESTEP 23602 / EPSILON 0.9551562000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.005673e+12
# Tally is -73
# TIMESTEP 23603 / EPSILON 0.9551543000000207 / ACTION 0 / REWARD 0 / Q_MAX 4.204056e+11
# Tally is -73
# TIMESTEP 23604 / EPSILON 0.9551524000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.991719e+11
# Tally is -73
# TIMESTEP 23605 / EPSILON 0.9551505000000207 / ACTION 2 / REWARD 0 / Q_MAX -2.510520e+11
# Tally is -73
# TIMESTEP 23606 / EPSILON 0.9551486000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.019936e+12
# Tally is -73
# TIMESTEP 23607 / EPSILON 0.9551467000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.162138e+12
# Tally is -73
# TIMESTEP 23608 / EPSILON 0.9551448000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.188047e+12
# Tally is -73
# TIMESTEP 23609 / EPSILON 0.9551429000000207 / ACTION 2 / REWARD 0 / Q_MAX -2.801188e+11
# Tally is -73
# TIMESTEP 23610 / EPSILON 0.9551410000000207 / ACTION 1 / REWARD 0 / Q_MAX -3.169270e+11
# Tally is -73
# TIMESTEP 23611 / EPSILON 0.9551391000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.905822e+12
# Tally is -73
# TIMESTEP 23612 / EPSILON 0.9551372000000207 / ACTION 0 / REWARD 0 / Q_MAX -1.742533e+11
# Tally is -73
# TIMESTEP 23613 / EPSILON 0.9551353000000207 / ACTION 2 / REWARD 0 / Q_MAX 8.193955e+11
# Tally is -73
# TIMESTEP 23614 / EPSILON 0.9551334000000207 / ACTION 0 / REWARD 0 / Q_MAX 9.265253e+11
# Tally is -73
# TIMESTEP 23615 / EPSILON 0.9551315000000207 / ACTION 1 / REWARD 0 / Q_MAX -9.031225e+11
# Tally is -73
# TIMESTEP 23616 / EPSILON 0.9551296000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.329314e+12
# Tally is -73
# TIMESTEP 23617 / EPSILON 0.9551277000000207 / ACTION 2 / REWARD 0 / Q_MAX -5.788905e+11
# Tally is -73
# TIMESTEP 23618 / EPSILON 0.9551258000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.779969e+12
# Tally is -73
# TIMESTEP 23619 / EPSILON 0.9551239000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.791054e+12
# Tally is -73
# TIMESTEP 23620 / EPSILON 0.9551220000000207 / ACTION 1 / REWARD 0 / Q_MAX 4.054476e+12
# Tally is -73
# TIMESTEP 23621 / EPSILON 0.9551201000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.957172e+12
# Tally is -73
# TIMESTEP 23622 / EPSILON 0.9551182000000207 / ACTION 2 / REWARD 0 / Q_MAX 4.281802e+12
# Tally is -73
# TIMESTEP 23623 / EPSILON 0.9551163000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.978122e+12
# Tally is -73
# TIMESTEP 23624 / EPSILON 0.9551144000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.572610e+12
# Tally is -73
# TIMESTEP 23625 / EPSILON 0.9551125000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.442316e+12
# Tally is -73
# TIMESTEP 23626 / EPSILON 0.9551106000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.730124e+12
# Tally is -73
# TIMESTEP 23627 / EPSILON 0.9551087000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.611681e+12
# Tally is -73
# TIMESTEP 23628 / EPSILON 0.9551068000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.104319e+12
# Tally is -73
# TIMESTEP 23629 / EPSILON 0.9551049000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.134673e+12
# Tally is -73
# TIMESTEP 23630 / EPSILON 0.9551030000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.846786e+12
# Tally is -73
# TIMESTEP 23631 / EPSILON 0.9551011000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.071144e+12
# Tally is -73
# TIMESTEP 23632 / EPSILON 0.9550992000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.255547e+12
# Tally is -73
# TIMESTEP 23633 / EPSILON 0.9550973000000207 / ACTION 0 / REWARD 0 / Q_MAX 5.281446e+11
# Tally is -73
# TIMESTEP 23634 / EPSILON 0.9550954000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.713128e+12
# Tally is -73
# TIMESTEP 23635 / EPSILON 0.9550935000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.823795e+12
# Tally is -73
# TIMESTEP 23636 / EPSILON 0.9550916000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.847525e+11
# Tally is -73
# TIMESTEP 23637 / EPSILON 0.9550897000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.046522e+12
# Tally is -73
# TIMESTEP 23638 / EPSILON 0.9550878000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.802321e+12
# Tally is -73
# TIMESTEP 23639 / EPSILON 0.9550859000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.815556e+12
# Tally is -73
# TIMESTEP 23640 / EPSILON 0.9550840000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.814367e+12
# Tally is -73
# TIMESTEP 23641 / EPSILON 0.9550821000000207 / ACTION 0 / REWARD 0 / Q_MAX 3.213947e+12
# Tally is -73
# TIMESTEP 23642 / EPSILON 0.9550802000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.115549e+12
# Tally is -73
# TIMESTEP 23643 / EPSILON 0.9550783000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.582303e+12
# Tally is -73
# TIMESTEP 23644 / EPSILON 0.9550764000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.454803e+12
# Tally is -73
# TIMESTEP 23645 / EPSILON 0.9550745000000207 / ACTION 0 / REWARD 0 / Q_MAX 3.480119e+12
# Tally is -73
# TIMESTEP 23646 / EPSILON 0.9550726000000207 / ACTION 2 / REWARD 0 / Q_MAX 5.435171e+12
# Tally is -73
# TIMESTEP 23647 / EPSILON 0.9550707000000207 / ACTION 0 / REWARD 0 / Q_MAX 5.808965e+12
# Tally is -73
# TIMESTEP 23648 / EPSILON 0.9550688000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.929378e+12
# Tally is -73
# TIMESTEP 23649 / EPSILON 0.9550669000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.132269e+12
# Tally is -73
# TIMESTEP 23650 / EPSILON 0.9550650000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.210231e+12
# Tally is -73
# TIMESTEP 23651 / EPSILON 0.9550631000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.367336e+12
# Tally is -73
# TIMESTEP 23652 / EPSILON 0.9550612000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.227822e+12
# Tally is -73
# TIMESTEP 23653 / EPSILON 0.9550593000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.920044e+12
# Tally is -73
# TIMESTEP 23654 / EPSILON 0.9550574000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.651208e+12
# Tally is -73
# TIMESTEP 23655 / EPSILON 0.9550555000000207 / ACTION 0 / REWARD 0 / Q_MAX 3.933062e+12
# Tally is -73
# TIMESTEP 23656 / EPSILON 0.9550536000000207 / ACTION 2 / REWARD 0 / Q_MAX 5.407912e+12
# Tally is -73
# TIMESTEP 23657 / EPSILON 0.9550517000000207 / ACTION 2 / REWARD 0 / Q_MAX 6.110497e+12
# Tally is -73
# TIMESTEP 23658 / EPSILON 0.9550498000000207 / ACTION 0 / REWARD 0 / Q_MAX 6.153456e+12
# Tally is -73
# TIMESTEP 23659 / EPSILON 0.9550479000000207 / ACTION 2 / REWARD 0 / Q_MAX 5.463896e+12
# Tally is -73
# TIMESTEP 23660 / EPSILON 0.9550460000000207 / ACTION 0 / REWARD 0 / Q_MAX 5.874049e+12
# Tally is -73
# TIMESTEP 23661 / EPSILON 0.9550441000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.912807e+12
# Tally is -73
# TIMESTEP 23662 / EPSILON 0.9550422000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.455164e+12
# Tally is -73
# TIMESTEP 23663 / EPSILON 0.9550403000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.863596e+12
# Tally is -73
# TIMESTEP 23664 / EPSILON 0.9550384000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.596847e+12
# Tally is -73
# TIMESTEP 23665 / EPSILON 0.9550365000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.966284e+12
# Tally is -73
# TIMESTEP 23666 / EPSILON 0.9550346000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.668461e+12
# Tally is -73
# TIMESTEP 23667 / EPSILON 0.9550327000000207 / ACTION 0 / REWARD 0 / Q_MAX 3.827844e+12
# Tally is -73
# TIMESTEP 23668 / EPSILON 0.9550308000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.331916e+12
# Tally is -73
# TIMESTEP 23669 / EPSILON 0.9550289000000207 / ACTION 2 / REWARD 0 / Q_MAX 3.194776e+12
# Tally is -73
# TIMESTEP 23670 / EPSILON 0.9550270000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.576384e+12
# Tally is -73
# TIMESTEP 23671 / EPSILON 0.9550251000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.349116e+12
# Tally is -73
# TIMESTEP 23672 / EPSILON 0.9550232000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.210634e+12
# Tally is -73
# TIMESTEP 23673 / EPSILON 0.9550213000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.208489e+12
# Tally is -73
# TIMESTEP 23674 / EPSILON 0.9550194000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.384354e+12
# Tally is -73
# TIMESTEP 23675 / EPSILON 0.9550175000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.606918e+12
# Tally is -73
# TIMESTEP 23676 / EPSILON 0.9550156000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.869663e+12
# Tally is -73
# TIMESTEP 23677 / EPSILON 0.9550137000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.890195e+12
# Tally is -73
# TIMESTEP 23678 / EPSILON 0.9550118000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.808044e+12
# Tally is -73
# TIMESTEP 23679 / EPSILON 0.9550099000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.532784e+12
# Tally is -73
# TIMESTEP 23680 / EPSILON 0.9550080000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.457315e+12
# Tally is -73
# TIMESTEP 23681 / EPSILON 0.9550061000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.631945e+12
# Tally is -73
# TIMESTEP 23682 / EPSILON 0.9550042000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.438108e+12
# Tally is -73
# TIMESTEP 23683 / EPSILON 0.9550023000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.615070e+12
# Tally is -73
# TIMESTEP 23684 / EPSILON 0.9550004000000207 / ACTION 1 / REWARD 0 / Q_MAX 3.150859e+12
# Tally is -73
# TIMESTEP 23685 / EPSILON 0.9549985000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.508364e+12
# Tally is -73
# TIMESTEP 23686 / EPSILON 0.9549966000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.195015e+12
# Tally is -73
# TIMESTEP 23687 / EPSILON 0.9549947000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.158011e+12
# Tally is -73
# TIMESTEP 23688 / EPSILON 0.9549928000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.726724e+12
# Tally is -74
# TIMESTEP 23689 / EPSILON 0.9549909000000207 / ACTION 2 / REWARD -1 / Q_MAX 1.911349e+12
# Tally is -74
# TIMESTEP 23690 / EPSILON 0.9549890000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.902646e+12
# Tally is -74
# TIMESTEP 23691 / EPSILON 0.9549871000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.202648e+12
# Tally is -74
# TIMESTEP 23692 / EPSILON 0.9549852000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.514091e+12
# Tally is -74
# TIMESTEP 23693 / EPSILON 0.9549833000000207 / ACTION 1 / REWARD 0 / Q_MAX 2.195322e+12
# Tally is -74
# TIMESTEP 23694 / EPSILON 0.9549814000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.659009e+12
# Tally is -74
# TIMESTEP 23695 / EPSILON 0.9549795000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.711046e+12
# Tally is -74
# TIMESTEP 23696 / EPSILON 0.9549776000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.474193e+12
# Tally is -74
# TIMESTEP 23697 / EPSILON 0.9549757000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.804369e+12
# Tally is -74
# TIMESTEP 23698 / EPSILON 0.9549738000000207 / ACTION 0 / REWARD 0 / Q_MAX 1.823794e+12
# Tally is -74
# TIMESTEP 23699 / EPSILON 0.9549719000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.556609e+12
# Tally is -74
# TIMESTEP 23700 / EPSILON 0.9549700000000207 / ACTION 0 / REWARD 0 / Q_MAX 2.196051e+12
# Tally is -74
# TIMESTEP 23701 / EPSILON 0.9549681000000207 / ACTION 2 / REWARD 0 / Q_MAX 2.803613e+12
# Tally is -74
# TIMESTEP 23702 / EPSILON 0.9549662000000207 / ACTION 1 / REWARD 0 / Q_MAX 1.758559e+12
# Tally is -74
# TIMESTEP 23703 / EPSILON 0.9549643000000207 / ACTION 2 / REWARD 0 / Q_MAX 1.460684e+12
# Tally is -74
# TIMESTEP 23704 / EPSILON 0.9549624000000208 / ACTION 2 / REWARD 0 / Q_MAX 1.273680e+12
# Tally is -74
# TIMESTEP 23705 / EPSILON 0.9549605000000208 / ACTION 0 / REWARD 0 / Q_MAX 1.531816e+12
# Tally is -74
# TIMESTEP 23706 / EPSILON 0.9549586000000208 / ACTION 0 / REWARD 0 / Q_MAX 1.700921e+12
# Tally is -74
# TIMESTEP 23707 / EPSILON 0.9549567000000208 / ACTION 0 / REWARD 0 / Q_MAX 2.147525e+12
# Tally is -74
# TIMESTEP 23708 / EPSILON 0.9549548000000208 / ACTION 2 / REWARD 0 / Q_MAX 1.140939e+12
# Tally is -74
# TIMESTEP 23709 / EPSILON 0.9549529000000208 / ACTION 0 / REWARD 0 / Q_MAX 1.600934e+12
# Tally is -74
# TIMESTEP 23710 / EPSILON 0.9549510000000208 / ACTION 1 / REWARD 0 / Q_MAX 1.296920e+12
# Tally is -74
# TIMESTEP 23711 / EPSILON 0.9549491000000208 / ACTION 0 / REWARD 0 / Q_MAX 1.142555e+12
# Tally is -74
# TIMESTEP 23712 / EPSILON 0.9549472000000208 / ACTION 0 / REWARD 0 / Q_MAX 6.998889e+11
# Tally is -74
# TIMESTEP 23713 / EPSILON 0.9549453000000208 / ACTION 2 / REWARD 0 / Q_MAX 1.721658e+12
# Tally is -74
# TIMESTEP 23714 / EPSILON 0.9549434000000208 / ACTION 0 / REWARD 0 / Q_MAX 6.667184e+11
# Tally is -74
# TIMESTEP 23715 / EPSILON 0.9549415000000208 / ACTION 1 / REWARD 0 / Q_MAX 1.020608e+12
# Tally is -74
# TIMESTEP 23716 / EPSILON 0.9549396000000208 / ACTION 2 / REWARD 0 / Q_MAX 5.108440e+11
# Tally is -74
# TIMESTEP 23717 / EPSILON 0.9549377000000208 / ACTION 1 / REWARD 0 / Q_MAX 5.453724e+11
# Tally is -74
# TIMESTEP 23718 / EPSILON 0.9549358000000208 / ACTION 0 / REWARD 0 / Q_MAX 9.441855e+11
# Tally is -74
# TIMESTEP 23719 / EPSILON 0.9549339000000208 / ACTION 2 / REWARD 0 / Q_MAX 6.732272e+11
# Tally is -74
# TIMESTEP 23720 / EPSILON 0.9549320000000208 / ACTION 1 / REWARD 0 / Q_MAX 5.904567e+11
# Tally is -74
# TIMESTEP 23721 / EPSILON 0.9549301000000208 / ACTION 2 / REWARD 0 / Q_MAX 7.662626e+11
# Tally is -74
# TIMESTEP 23722 / EPSILON 0.9549282000000208 / ACTION 2 / REWARD 0 / Q_MAX 7.397581e+11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ca5f41f10208> in <module>()
#     185
#     186 if __name__ == "__main__":
# --> 187     main()
#
# <ipython-input-3-ca5f41f10208> in main()
#     182     inp, out = createGraph()
#     183     # train our graph on input and output with session variables
# --> 184     trainGraph(inp, out, sess)
#     185
#     186 if __name__ == "__main__":
#
# <ipython-input-3-ca5f41f10208> in trainGraph(inp, out, sess)
#     108     while(1):
#     109         # output tensor
# --> 110         out_t = out.eval(feed_dict={inp: [inp_t]})[0]
#     111         # argmax function
#     112         argmax_t = np.zeros([ACTIONS])
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\ops.py in eval(self, feed_dict, session)
#     711
#     712     """
# --> 713     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     714
#     715
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5155                        "the tensor's graph is different from the session's "
#    5156                        "graph.")
# -> 5157   return session.run(tensors, feed_dict)
#    5158
#    5159
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\users\rohan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
